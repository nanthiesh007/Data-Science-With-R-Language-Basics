# %% [markdown]
# ## T- Test:
#
#                    T-Test will tell the significance difference between the groups
#
#                    When to use T-Test:
#                           * Data are Independent
#                           * Datas are noramlly distributed (check distribution by applying skewness)
#
#                    Types of T-Test:
#                           * Paired T-Test (If the groups come from a single population)
#                           * Two-Sample T-Test (If the groups come from two different)
#                           * One-Sample T-Test (If there is one group being compared against a standard value)
#
#                    T-Test:
#                        * One-tailed T-Test (AIML < Cyber)
#                        * Two-tailed T-Test (AIML && Cyber)

# %% [markdown]
# ## T-Test Table:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 1:
#
#            Suppose a botanical wants to know if the mean height of certain species of plant is equal to 15 inches.
#            Sam collects a random sample of 12 plants and records each of its heights in inches.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2:
#
#            Data given for boys and girls height. Find if there is any significance difference in the boys
#            and girls heright with alpha 0.025

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 3:
#
#              A Researcher wants to test a new anti-hunger weight loss pill. They have 10 people, rate their hunger before
#              and after taking the pill. Does the pill do anything?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#        Syntax:
#
#            Type:
#            Tail:
#            alpha(level of significance) :
#            solve
#
#            df = Critical value
#            Calculated Value < Critical Value
#                 The Accept the Null Hypothesis

# %% [markdown]
# ## Probability Distribution:

# %%
x = c(14,14,16,13,12,17,15,14,15,13,15,14)

# %%
length(x)
# Out:
# [1] 12

# %%
# t.test = is used for the which sample test
# mu = hypothesis mean value
# conf.level = level of significance

t.test(x, mu=15, conf.level=0.05)
# Out:
# 	One Sample t-test
#
# data:  x
# t = -1.6848, df = 11, p-value = 0.1201
# alternative hypothesis: true mean is not equal to 15
# 5 percent confidence interval:
#  14.30795 14.35872
# sample estimates:
# mean of x
#  14.33333

# %%
# alternative =  to mention the number of tails

# %% [markdown]
#              * In R code it uses the parameter alternative , it will accept 3 value
#
#                         * "lesser" ot "greater" is the one tailed T-Test
#                         * "two.sided" is the two tailed T-Test

# %%
t.test(x, mu=15, conf.level=0.05, alternative = "two.sided")
# Out:
# 	One Sample t-test
#
# data:  x
# t = -1.6848, df = 11, p-value = 0.1201
# alternative hypothesis: true mean is not equal to 15
# 5 percent confidence interval:
#  14.30795 14.35872
# sample estimates:
# mean of x
#  14.33333

# %%
t.test(x, mu=15, conf.level=0.05, alternative= "greater")
# Out:
# 	One Sample t-test
#
# data:  x
# t = -1.6848, df = 11, p-value = 0.9399
# alternative hypothesis: true mean is greater than 15
# 5 percent confidence interval:
#  15.04394      Inf
# sample estimates:
# mean of x
#  14.33333

# %%
t.test(x, mu=15, conf.level=0.05, alternative = "less")
# Out:
# 	One Sample t-test
#
# data:  x
# t = -1.6848, df = 11, p-value = 0.06007
# alternative hypothesis: true mean is less than 15
# 5 percent confidence interval:
#      -Inf 13.62273
# sample estimates:
# mean of x
#  14.33333

# %% [markdown]
#            For Two Sample Cases:
#
#                  *  If its a two sample special use paird = TRUE
#                  *  If its a two sample use paird = FALSE

# %%
x1 = c(14,8,7,13)
x2 = c(8,6,4,14)

# %%
t.test(x1, x2, paired= FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  x1 and x2
# t = 0.89803, df = 5.7596, p-value = 0.4051
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.381432  9.381432
# sample estimates:
# mean of x mean of y
#      10.5       8.0

# %%
t.test(x1, x2, paired= FALSE,  conf.level=0.01)
# Out:
# 	Welch Two Sample t-test
#
# data:  x1 and x2
# t = 0.89803, df = 5.7596, p-value = 0.4051
# alternative hypothesis: true difference in means is not equal to 0
# 1 percent confidence interval:
#  2.463568 2.536432
# sample estimates:
# mean of x mean of y
#      10.5       8.0

# %%
b = c(9,10,7,5,7,5,9,6,8,7)
a = c(7,6,5,4,4,6,7,5,5,7)
x = c(2,4,2,1,3,-1,2,1,3,0)

# %%
t.test(b,a,paired=TRUE, conf.level=0.05)
# Out:
# 	Paired t-test
#
# data:  b and a
# t = 3.5973, df = 9, p-value = 0.005773
# alternative hypothesis: true difference in means is not equal to 0
# 5 percent confidence interval:
#  1.669529 1.730471
# sample estimates:
# mean of the differences
#                     1.7

# %% [markdown]
# ## Binomial Distribution:
#
#                  * A Binomial Distribution is a discrete probability distribution
#                  * It describe the outcome of n independent trials in an experiment
#
# ![image.png](attachment:image.png)
#
#                x = 0,1,2,3,......
#                n = independent trial
#                p = probability of successfull trial
#                x = sucessful outcomes in an experiment of "n"
#                q = (1 - p)

# %%
# pbinom = is used for binomial distribution
# pbinom(successful outcome, size, probability)

pbinom(4, size = 12, prob = 0.2)  # probability = 1/5 = 0.2
# Out:
# [1] 0.9274445

# %% [markdown]
# ##  Poison Distribution:
#
#                       Poison is a probability ditribution of independent of event occurance in an interval
#
# ![image.png](attachment:image.png)
#
#                      x = 0,1,2,3,.......
#                      λ = Mean Occurance per interval
#                      e = Euler's Constant ~ 2.71828

# %%
# ppois = is used for poison distribution
# ppois( ,lambda)

ppois(16, lambda = s)
# Out:
# Error in ppois(16, lambda = s): object 's' not found
# Traceback:
#
# 1. ppois(16, lambda = s)

# %% [markdown]
# ## Continuous Uniform Distribution:
#
#                     Continuous Uniform Distribution is a probability distribution of the random numbers selection from the
#                     continuous interval between A to B
#
# ![image.png](attachment:image.png)

# %%
# runif = is used for continuous Uniform Distribution
# runif(number of numbers needed, minimum , maximum)

runif(10, min=1, max =5)
# Out:
#  [1] 3.165209 2.248533 1.852749 3.910637 3.437759 4.237838 4.693049 1.708623
#  [9] 4.589092 4.325845

# %%
a = runif(10, min=1, max =5)
plot(density(a))
# Out:
# Plot with title "density.default(x = a)"

# %% [markdown]
# ## Exponential Distribution:
#
#                        Exponential Distribution describe the arrival time of a randomly reccuring independent event
#                        sequence
#
#                        1/(µ) e^(-x/u)
#
#                        µ = mean waiting time for the next event
#                        e = Euler's Constant ~ 2.71828
#                        x = random variable

# %%
# pexp() = is used for exponential distribution
# pexp(value, rate)

pexp(2, rate = 1/3)
# Out:
# [1] 0.4865829

# %% [markdown]
# ## Normal Distribution:
#
#                         Normal Distribution definied by the following probablity density function, where
#
# ![image.png](attachment:image.png)
#
#                             * σ = Variance
#                             * μ = Population Mean
#                             * x = Value of the variable or data
#                             *

# %%
# pnorm() = is used for normal distribution
# pnorm(value, mean , standard deviation)

pnorm(84, mean=72, sd=15.2)
# Out:
# [1] 0.7850824
